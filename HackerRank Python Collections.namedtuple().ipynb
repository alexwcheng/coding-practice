# %% [markdown]
# # HackerRank Python Collections.namedtuple()

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%209.56.46%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%209.56.46%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%209.57.00%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%209.57.00%20PM.png)

# %%
from collections import namedtuple

N = int(input())
fields = input().split()

total = 0
for i in range(N):
    students = namedtuple('student',fields)
    field1, field2, field3,field4 = input().split()
    student = students(field1,field2,field3,field4)
    total += int(student.MARKS)
print('{:.2f}'.format(total/N))
