# %% [markdown]
# # HackerRank Python Company Logo

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.07.21%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.07.21%20PM.png)

# %%
from collections import Counter

chars = Counter(input()).items()

for char, n in sorted(chars, key=lambda c: (-c[1], c[0]))[:3]:
    print(char, n)
# Out:
# aabbbccde
# b 3
# a 2
# c 2
