# %% [markdown]
# # HackerRank SQL Select All

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%209.52.53%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%209.52.53%20PM.png)

# %%
# pseudocode

SELECT * FROM CITY
