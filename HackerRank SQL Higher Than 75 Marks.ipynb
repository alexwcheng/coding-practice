# %% [markdown]
# # HackerRank SQL Higher Than 75 Marks

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.34.59%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.34.59%20PM.png)

# %%
# pseudocode
SELECT NAME FROM STUDENTS
WHERE MARKS>75
ORDER BY RIGHT(NAME,3), ID ASC;
