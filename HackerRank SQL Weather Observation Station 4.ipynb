# %% [markdown]
# # HackerRank SQL Weather Observation Station 4

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.10.49%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.10.49%20PM.png)

# %%
# pseudocode
SELECT COUNT(CITY) - COUNT(DISTINCT(CITY)) FROM STATION
