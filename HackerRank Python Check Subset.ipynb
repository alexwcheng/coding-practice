# %% [markdown]
# # HackerRank Python Check Subset

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2011.02.57%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2011.02.57%20PM.png)

# %%
for i in range(int(input())):
    _, a = input(), set(map(int, input().split()))
    _, b = input(), set(map(int, input().split()))
    print(a.issubset(b))
