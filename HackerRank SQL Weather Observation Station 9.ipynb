# %% [markdown]
# # HackerRank SQL Weather Observation Station 9

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.54.38%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.54.38%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION
WHERE LEFT(CITY,1) NOT IN ('a','e','i','o','u')
