# %% [markdown]
# # HackerRank Python Collections.OrderedDict()

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%209.59.41%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%209.59.41%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.00.03%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.00.03%20PM.png)

# %%
from collections import OrderedDict
d = OrderedDict()
for _ in range(int(input())):
    item, space, quantity = input().rpartition(' ')
    d[item] = d.get(item, 0) + int(quantity)
for item, quantity in d.items():
    print(item, quantity)
# Out:
# 4
# BANANA FRIES 12
# POTATO CHIPS 30
# APPLE JUICE 10
# POTATO CHIPS 60
# BANANA FRIES 12
# POTATO CHIPS 90
# APPLE JUICE 10
