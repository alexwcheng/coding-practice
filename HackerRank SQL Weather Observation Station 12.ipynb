# %% [markdown]
# # HackerRank SQL Weather Observation Station 12

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2011.07.36%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2011.07.36%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION 
WHERE CITY REGEXP '^[^aeiou].*[^aeiou]$'
