# %% [markdown]
# # HackerRank SQL Employee Salaries

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.45.37%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.45.37%20PM.png)

# %%
# pseudocode
SELECT NAME FROM EMPLOYEE
WHERE SALARY > 2000
AND MONTHS < 10;
