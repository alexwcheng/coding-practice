# %% [markdown]
# # HackerRank SQL Weather Observation Station 19

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%208.19.35%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%208.19.35%20PM.png)

# %%
# recall pythagorean theorem:
x**2 + y**2 = z**2
z = sqrt(x**2 + y**2)

# %%
# pseudocode
SELECT ROUND(SQRT(POW(MAX(LAT_N)-MIN(LAT_N),2)+
POW(MAX(LONG_W)-MIN(LONG_W),2)),4) 
FROM STATION;
