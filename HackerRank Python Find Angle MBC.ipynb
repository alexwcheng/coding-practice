# %% [markdown]
# # HackerRank Python Triangle Quest 2

# %% [markdown]
# ![Screen%20Shot%202020-08-18%20at%207.59.06%20PM.png](attachment:Screen%20Shot%202020-08-18%20at%207.59.06%20PM.png)

# %%
for x in range(1,int(input())+1):
    print(((10**x - 1)//9)**2)
# Out:
# 10
# 1
# 121
# 12321
# 1234321
# 123454321
# 12345654321
# 1234567654321
# 123456787654321
# 12345678987654321
# 1234567900987654321
