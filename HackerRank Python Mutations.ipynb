# %% [markdown]
# # HackerRank Python Mutations

# %% [markdown]
# ![Screen%20Shot%202020-08-17%20at%2011.37.18%20PM.png](attachment:Screen%20Shot%202020-08-17%20at%2011.37.18%20PM.png)

# %%
def mutate_string(string, position, character):
    return string[:position] + character + string[position + 1:]

if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)
# Out:
# alexcheng
# 3 c
# aleccheng
