# %% [markdown]
# # HackerRank Python Sum and Prod

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.20.28%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.20.28%20PM.png)

# %%
import numpy
N, M = map(int, input().split())
A = numpy.array([input().split() for _ in range(N)],int)
print(numpy.prod(numpy.sum(A, axis=0), axis=0))
# Out:
# 2 2
# 1 2
# 3 4
# 24
