# %% [markdown]
# # HackerRank SQL Type Of Triangle

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%2010.28.28%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%2010.28.28%20PM.png)

# %%
# pseudocode
SELECT IF (A+B<=C OR B+C<=A OR A+C<=B, 'NOT A TRIANGLE',
IF(A=B AND B=C, 'EQUILATERAL'
IF(A=B OR B=C OR A=C, 'ISOSCELES', 'SCALENE')))
FROM TRIANGLES AS T;
