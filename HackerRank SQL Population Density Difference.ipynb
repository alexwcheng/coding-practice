# %% [markdown]
# # HackerRank SQL Population Density Difference

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%2010.02.28%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%2010.02.28%20PM.png)

# %%
# pseudocode
SELECT (MAX(POPULATION)-MIN(POPULATION)) FROM CITY;
