# %% [markdown]
# # HackerRank SQL Weather Observation Station 7

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.42.31%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.42.31%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION 
WHERE RIGHT(CITY,1) IN ('a','e','i','o','u');
