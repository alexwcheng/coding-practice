# %% [markdown]
# # HackerRank SQL Japanese Cities' Attributes

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.00.07%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.00.07%20PM.png)

# %%
# pseudocode
SELECT * FROM CITY
WHERE COUNTRYCODE='JPN'
