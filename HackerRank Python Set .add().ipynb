# %% [markdown]
# # HackerRank Python Set .add()

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%207.07.57%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%207.07.57%20PM.png)

# %%
s = set('HackerRank')
s.add('H')
print(s)
# Out:
# {'k', 'n', 'R', 'H', 'a', 'c', 'r', 'e'}

# %%
print(s.add('HackerRank'))
# Out:
# None

# %%
print(s)
# Out:
# {'k', 'n', 'R', 'H', 'a', 'c', 'r', 'e', 'HackerRank'}

# %%
# SOLUTION:
# This can be done without the .add() method:
# we just want the length of the set of the inputs we provide...no need for .add()

print(len(set([str(input()) for x in range(int(input()))])))
# Out:
# 5
# USA
# China
# USA
# Norway
# Sweden
# 4
