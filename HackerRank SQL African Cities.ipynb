# %% [markdown]
# # HackerRank SQL African Cities

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%2010.13.45%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%2010.13.45%20PM.png)

# %%
# pseudocode
SELECT CITY.NAME FROM CITY INNER JOIN COUNTRY
ON COUNTRYCODE = CODE
WHERE CONTINENT = 'Africa';

# %%
# alternative solution:
SELECT CITY.NAME FROM CITY, COUNTRY
WHERE CODE = COUNTRYCODE AND CONTINENT = 'Africa'
