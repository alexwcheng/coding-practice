# %% [markdown]
# # HackerRank SQL Weather Observation Station 10

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.57.14%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.57.14%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION
WHERE RIGHT(CITY,1) NOT IN ('a','e','i','o','u');
