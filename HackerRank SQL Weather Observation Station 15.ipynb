# %% [markdown]
# # HackerRank SQL Weather Observation Station 15

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%207.15.26%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%207.15.26%20PM.png)

# %%
# pseudocode
SELECT ROUND(LONG_W, 4)
FROM STATION
WHERE LAT_N < 137.2345
ORDER BY LAT_N DESC
LIMIT 1
