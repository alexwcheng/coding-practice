# %% [markdown]
# # HackerRank Python Min and Max

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.22.17%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.22.17%20PM.png)

# %%
import numpy
N, M = map(int, input().split())
A = numpy.array([input().split() for _ in range(N)],int)
print(numpy.max(numpy.min(A, axis=1), axis=0))
# Out:
# 4 2
# 2 5
# 3 7
# 1 3
# 4 0
# 3
