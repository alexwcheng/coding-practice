# %% [markdown]
# # HackerRank SQL Japan Population

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%2010.00.41%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%2010.00.41%20PM.png)

# %%
# pseudocode
SELECT SUM(POPULATION) FROM CITY
WHERE COUNTRYCODE='JPN';
