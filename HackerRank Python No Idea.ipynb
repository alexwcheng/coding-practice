# %% [markdown]
# # HackerRank Python No Idea

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.29.35%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.29.35%20PM.png)

# %%
n, m = input().split()
arr = [int(x) for x in input().split()]
A = set([int(y) for y in input().split()])
B = set([int(z) for z in input().split()])
count = [0 + 1 if x in A else 0-1 if x in B else 0 + 0 for x in arr]
print(sum(count))
# Out:
# 3 2
# 1 5 3
# 3 1
# 5 7
# 1
