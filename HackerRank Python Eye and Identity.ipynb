# %% [markdown]
# # HackerRank Python Eye and Identity

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.13.39%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.13.39%20PM.png)

# %%
import numpy
print(str(numpy.eye(*map(int,input().split()))).replace('1',' 1').replace('0',' 0'))
# Out:
# 3 3
# [[ 1.  0.  0.]
#  [ 0.  1.  0.]
#  [ 0.  0.  1.]]
