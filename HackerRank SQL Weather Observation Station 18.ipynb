# %% [markdown]
# # HackerRank SQL Weather Observation Station 18

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%208.08.22%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%208.08.22%20PM.png)

# %%
SELECT TRUNCATE((MAX(LAT_N) - MIN(LAT_N)) + (MAX(LONG_W) - MIN(LONG_W)),4)
FROM STATION;
