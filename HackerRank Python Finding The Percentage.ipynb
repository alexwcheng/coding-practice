# %% [markdown]
# # HackerRank Python Finding The Percentage

# %% [markdown]
# ![Screen%20Shot%202020-08-17%20at%2011.22.04%20PM.png](attachment:Screen%20Shot%202020-08-17%20at%2011.22.04%20PM.png)

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    total_marks = sum(student_marks[query_name])
    average_marks = total_marks/3 
    print("%.2f"%(average_marks))
# Out:
# 2
# Alex 56 34 89
# Alex2 45 87 65
# Alex
# 59.67
