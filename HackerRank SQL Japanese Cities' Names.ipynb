# %% [markdown]
# # HackerRank SQL Japanese Cities' Names

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.01.58%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.01.58%20PM.png)

# %%
# pseudocode
SELECT NAME FROM CITY
WHERE COUNTRYCODE='JPN'
