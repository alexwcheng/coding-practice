# %% [markdown]
# # HackerRank Python String Split And Join

# %% [markdown]
# ![Screen%20Shot%202020-08-18%20at%207.41.36%20PM.png](attachment:Screen%20Shot%202020-08-18%20at%207.41.36%20PM.png)

# %%
def split_and_join(line):
    x=line.split(" ") 
    x='-'.join(x)    
    return x
if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
# Out:
# this is a string
# this-is-a-string
