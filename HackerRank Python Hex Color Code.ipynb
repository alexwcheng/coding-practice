# %% [markdown]
# # HackerRank Python Hex Color Code

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%206.09.58%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%206.09.58%20PM.png)

# %%
#this is a regex problem.
import re, sys
[print(j) for i in sys.stdin for j in re.findall('[\s:](#[a-f0-9]{6}|#[a-f0-9]{3})', i, re.I)]
# Out:
# []
