# %% [markdown]
# # HackerRank SQL Weather Observation Station 3

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.07.08%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.07.08%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION
WHERE ID % 2 = 0
