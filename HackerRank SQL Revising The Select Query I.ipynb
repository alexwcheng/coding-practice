# %% [markdown]
# # HackerRank SQL Revising The Select Query I

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.28.44%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.28.44%20PM.png)

# %%
# pseudocode
SELECT * FROM CITY
WHERE COUNTRYCODE='USA'
AND POPULATION>100000;
