# %% [markdown]
# # HackerRank SQL Revising The Select Query II

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.34.33%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.34.33%20PM.png)

# %%
# pseudocode
SELECT NAME FROM CITY
WHERE COUNTRYCODE='USA'
AND POPULATION>120000;
