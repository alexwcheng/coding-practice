# %% [markdown]
# # HackerRank SQL Weather Observation Station 20

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%209.17.55%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%209.17.55%20PM.png)

# %%
# pseudocode
SELECT ROUND(S.LAT_N,4) 
FROM STATION S WHERE (SELECT ROUND(COUNT(S.ID)/2)-1 FROM STATION) = 
(SELECT COUNT(S1.ID) FROM STATION S1 WHERE S1.LAT_N > S.LAT_N);
