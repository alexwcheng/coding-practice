# %% [markdown]
# # HackerRank SQL Weather Observation Station 2

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.57.44%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.57.44%20PM.png)

# %%
# pseudocode
SELECT ROUND(SUM(LAT_N),2), ROUND(SUM(LONG_W),2) FROM STATION;
