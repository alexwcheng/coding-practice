# %% [markdown]
# # HackerRank Python Find A String

# %% [markdown]
# ![Screen%20Shot%202020-08-17%20at%2011.41.14%20PM.png](attachment:Screen%20Shot%202020-08-17%20at%2011.41.14%20PM.png)

# %%
def count_substring(string, sub_string):
    count = 0
    for i in range(len(string)):
        if string[i:].startswith(sub_string):
            count += 1
    return count

if __name__ == '__main__':
    string = input().strip()
    sub_string = input().strip()
    
    count = count_substring(string, sub_string)
    print(count)
# Out:
# ABCDEFGEFGEFGFEDCBA
# EFG
# 3
