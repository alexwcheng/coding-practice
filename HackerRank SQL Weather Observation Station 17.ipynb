# %% [markdown]
# # HackerRank SQL Weather Observation Station 17

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%208.03.10%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%208.03.10%20PM.png)

# %%
# pseudocode
SELECT ROUND (LONG_W,4) FROM STATION 
WHERE LAT_N>38.7780 
ORDER BY LAT_N ASC LIMIT 1;
