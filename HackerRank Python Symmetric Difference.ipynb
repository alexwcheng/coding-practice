# %% [markdown]
# # HackerRank Python Symmetric Difference

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.26.12%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.26.12%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.26.26%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.26.26%20PM.png)

# %%
a,b = [set(input().split()) for _ in range(4)][1::2]
print(*sorted(a^b, key=int), sep='\n')
# Out:
# 4
# 2 4 5 9
# 4
# 2 4 11 12
# 5
# 9
# 11
# 12
