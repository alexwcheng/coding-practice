# %% [markdown]
# # HackerRank SQL Average Population

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%209.58.57%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%209.58.57%20PM.png)

# %%
# pseudocode
SELECT ROUND(AVG(POPULATION),0) FROM CITY
