# %% [markdown]
# # HackerRank SQL Select By ID

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%209.55.03%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%209.55.03%20PM.png)

# %%
# pseudocode
SELECT * FROM CITY
WHERE ID='1661'
