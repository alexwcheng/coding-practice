# %% [markdown]
# # HackerRank Python Capitalize!

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%207.32.57%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%207.32.57%20PM.png)

# %%
s = input()
for x in s[:].split():
    s = s.replace(x, x.capitalize())
print(s)
# Out:
# alexander cheng
# Alexander Cheng
