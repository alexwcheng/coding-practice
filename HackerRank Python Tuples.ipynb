# %% [markdown]
# # HackerRank Python Tuples

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%206.55.56%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%206.55.56%20PM.png)

# %%
# given
n = int(input())
integer_list = map(int, input().split())

# just need to convert "integer_list" to a tuple and assign to variable "t"
t = tuple(integer_list)

# now just print(hash(t))
print(hash(t))
# Out:
# 2
# 1 2
# 3713081631934410656
