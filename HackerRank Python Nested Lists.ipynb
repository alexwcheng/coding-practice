# %% [markdown]
# # HackerRank Python Nested Lists

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%207.00.51%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%207.00.51%20PM.png)

# %%
grades = []
for _ in range(0,int(input())):
    grades.append([input(), float(input())])

second_highest = sorted(list(set([grade for name, grade in grades])))[1]
print('\n'.join([a for a,b in sorted(grades) if b == second_highest]))
# Out:
# 3
# berry
# 34
# mark
# 67
# alex
# 87
# mark
