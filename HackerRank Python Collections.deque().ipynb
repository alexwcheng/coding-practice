# %% [markdown]
# # HackerRank Python Collections.deque()

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.02.56%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.02.56%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.03.06%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.03.06%20PM.png)

# %%
from collections import deque
d = deque()
for _ in range(int(input())):
    inp = input().split()
    getattr(d, inp[0])(*[inp[1]] if len(inp) > 1 else [])
print(*[item for item in d])
# Out:
# 6
# append 1
# append 2
# append 3
# appendleft 4
# pop
# popleft
# 1 2
