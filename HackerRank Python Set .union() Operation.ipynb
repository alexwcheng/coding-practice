# %% [markdown]
# # HackerRank Python Set .union() Operation

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.37.10%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.37.10%20PM.png)

# %%
n = input()
set_n = set(map(int, input().split()))
b = input()
set_b = set(map(int, input().split()))
print(len(set_n.union(set_b)))
