# %% [markdown]
# # HackerRank Python Set .symmetric_difference() Operation

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.44.24%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.44.24%20PM.png)

# %%
e, eStudents = int(input()), set(input().split())
f, fStudents = int(input()), set(input().split())

print(len(eStudents ^ fStudents))
# Out:
# 9
# 1 2 3 4 5 6 7 8 9
# 9
# 10 1 2 3 11 21 55 6 8
# 8
