# %% [markdown]
# # HackerRank Python What's Your Name?

# %% [markdown]
# ![Screen%20Shot%202020-08-17%20at%2011.26.41%20PM.png](attachment:Screen%20Shot%202020-08-17%20at%2011.26.41%20PM.png)

# %%
def print_full_name(a, b):
    print("Hello {} {}! You just delved into python.".format(a, b))
if __name__ == '__main__':
    first_name = input()
    last_name = input()
    print_full_name(first_name, last_name)
# Out:
# Alex
# Cheng
# Hello Alex Cheng! You just delved into python.
