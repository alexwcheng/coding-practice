# %% [markdown]
# # HackerRank SQL Average Population Of Each Continent

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%2010.20.28%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%2010.20.28%20PM.png)

# %%
# pseudocode
SELECT C.CONTINENT, FLOOR(AVG(CI.POPULATION)) AS 'AVG_POPULATION'
FROM CITY CI
INNER JOIN COUNTRY C
ON CI.COUNTRYCODE = C.CODE
GROUP BY C.CONTINENT;
