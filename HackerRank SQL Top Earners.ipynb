# %% [markdown]
# # HackerRank SQL Top Earners

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.49.40%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.49.40%20PM.png)

# %%
# pseudocode
SELECT (SALARY * MONTHS) AS EARNINGS,COUNT(*) 
FROM EMPLOYEE GROUP BY 1
ORDER BY EARNINGS DESC LIMIT 1;
