# %% [markdown]
# # HackerRank SQL Weather Observation Station 8

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.47.45%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.47.45%20PM.png)

# %%
# pseudocode
SELECT DISTINCT CITY FROM STATION 
WHERE LEFT(CITY,1) IN ('a','e','i','o','u')
AND RIGHT(CITY,1) IN ('a','e','i','o','u');
