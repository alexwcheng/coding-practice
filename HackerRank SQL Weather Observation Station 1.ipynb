# %% [markdown]
# # HackerRank SQL Weather Observation Station 1

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.03.55%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.03.55%20PM.png)

# %%
# pseudocode
SELECT CITY, STATE FROM STATION
