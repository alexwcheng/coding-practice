# %% [markdown]
# # HackerRank Python Set .intersection() Operation

# %% [markdown]
# ![Screen%20Shot%202020-08-18%20at%208.09.36%20PM.png](attachment:Screen%20Shot%202020-08-18%20at%208.09.36%20PM.png)

# %%
num1, st1, num2, st2 = (set(input().split()) for i in range(4))
print(len(st1.intersection(st2)))
# Out:
# 9
# 1 2 3 4 5 6 7 8 9
# 9
# 10 1 2 3 11 21 55 6 8
# 5
