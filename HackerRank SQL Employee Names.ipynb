# %% [markdown]
# # HackerRank SQL Employee Names

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%206.41.13%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%206.41.13%20PM.png)

# %%
# pseudocode
SELECT NAME FROM EMPLOYEE
ORDER BY NAME ASC;
