# %% [markdown]
# # HackerRank SQL Revising Aggregations - The Sum Function

# %% [markdown]
# ![Screen%20Shot%202020-06-22%20at%209.27.48%20PM.png](attachment:Screen%20Shot%202020-06-22%20at%209.27.48%20PM.png)

# %%
# pseudocode
SELECT SUM(POPULATION) FROM CITY
WHERE DISTRICT='California';
