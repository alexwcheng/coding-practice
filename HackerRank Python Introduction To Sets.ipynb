# %% [markdown]
# # HackerRank Python Introduction To Sets

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2010.18.45%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2010.18.45%20PM.png)

# %%
def average(array):
    # your code goes here
    return sum(set(array))/len(set(array))
if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)
# Out:
# 5
# 14 17 45 97 36
# 41.8
