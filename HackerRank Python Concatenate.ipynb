# %% [markdown]
# # HackerRank Python Concatenate

# %% [markdown]
# ![Screen%20Shot%202020-09-07%20at%2010.10.08%20PM.png](attachment:Screen%20Shot%202020-09-07%20at%2010.10.08%20PM.png)

# %%
import numpy as np
a, b, c = map(int,input().split())
arrA = np.array([input().split() for _ in range(a)],int)
arrB = np.array([input().split() for _ in range(b)],int)
print(np.concatenate((arrA, arrB), axis = 0))
# Out:
# 4 3 2
# 1 2
# 1 2
# 1 2
# 1 2
# 3 4
# 3 4
# 3 4
# [[1 2]
#  [1 2]
#  [1 2]
#  [1 2]
#  [3 4]
#  [3 4]
#  [3 4]]
