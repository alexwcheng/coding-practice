# %% [markdown]
# # HackerRank Python Swap Case

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%207.19.58%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%207.19.58%20PM.png)

# %%
n = str(input())
n.swapcase()
# Out:
# HackerRank
# 'hACKERrANK'
