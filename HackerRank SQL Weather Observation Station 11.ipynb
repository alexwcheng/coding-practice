# %% [markdown]
# # HackerRank SQL Weather Observation Station 11

# %% [markdown]
# ![Screen%20Shot%202020-06-21%20at%2010.59.41%20PM.png](attachment:Screen%20Shot%202020-06-21%20at%2010.59.41%20PM.png)

# %%
# Pseudocode
SELECT DISTINCT CITY FROM STATION 
WHERE CITY REGEXP '^[^aeiou]|[^aeiou]$';
