# %% [markdown]
# # HackerRank Python The Captain's Room

# %% [markdown]
# ![Screen%20Shot%202020-08-28%20at%2011.00.41%20PM.png](attachment:Screen%20Shot%202020-08-28%20at%2011.00.41%20PM.png)

# %%
K = int(input())
rooms = input().split()

rooms.sort()
capt_room = (set(rooms[0::2]) ^ set(rooms[1::2]))
print(capt_room.pop())
